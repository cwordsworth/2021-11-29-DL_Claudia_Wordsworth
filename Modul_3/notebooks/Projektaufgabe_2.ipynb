# %% [markdown]
# # Projektaufgabe: Grundlagen der Datenanalyse in Python

# %% [markdown]
# Die Pressestelle der San Francisco Public Library möchte einen Online-Artikel zum Kundenstamm der Bibliothek erstellen. Dazu hat sie Dir einen Datensatz geschickt, den Du auswerten sollst.
#
#     Erstelle eine Beschreibung des Datensatzes unter Verwendung des statistischen Grundvokabulars.
#     Lies den Datensatz ein.
#     Bereinige den Datensatz von fehlenden Werten und berechne die neue Variable Membership Duration.

# %%
import pandas as pd
Lib_Use = pd.read_csv("../data/Library_Usage.csv", na_values="None")

Lib_Use.head(10)
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 0                  ADULT                0               0
# 1                 0                  ADULT               31              22
# 2                 0                  ADULT                0               0
# 3                 0                  ADULT                0               0
# 4                 0                  ADULT              126              11
# 5                 3                 SENIOR                0               0
# 6                 0                  ADULT             3002            1689
# 7                 0                  ADULT                4               0
# 8                 0                  ADULT               20               0
# 9                 0                  ADULT                3               1
#
#         Age Range Home Library Code Home Library Definition  \
# 0  20 to 24 years                P1                    Park
# ...

# %% [markdown]
# Der Datensatz ist eine Vollstichprobe mit 15 verschiedenen Merkmalen. Die Merkmale sind nominal (Home Library Definition), metrisch (Total Checkouts) und kategorisch (Age Range).

# %%
Lib_Use.dropna(inplace=True)

# %%
Lib_Use
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 1                      0                  ADULT               31
# 4                      0                  ADULT              126
# 6                      0                  ADULT             3002
# 7                      0                  ADULT                4
# 8                      0                  ADULT               20
# ...                  ...                    ...              ...
# 423442                 2            YOUNG ADULT              608
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
#
#         Total Renewals       Age Range Home Library Code  \
# 1                   22  25 to 34 years                S7
# 4                   11  45 to 54 years                M2
# ...

# %%
#Berechnung der neuen Variablen Membership Duration:

Lib_Use['Circulation Active Month'] = pd.to_datetime(
    Lib_Use['Circulation Active Month'],
    errors='coerce',
    format="%B"
)

# %%
Lib_Use['Circulation Active Month']= Lib_Use['Circulation Active Month'].dt.month
Lib_Use["Membership Duration"]=(Lib_Use['Circulation Active Year'] - Lib_Use['Year Patron Registered'])*12 + Lib_Use['Circulation Active Month']

# %%
Lib_Use
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 1                      0                  ADULT               31
# 4                      0                  ADULT              126
# 6                      0                  ADULT             3002
# 7                      0                  ADULT                4
# 8                      0                  ADULT               20
# ...                  ...                    ...              ...
# 423442                 2            YOUNG ADULT              608
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
#
#         Total Renewals       Age Range Home Library Code  \
# 1                   22  25 to 34 years                S7
# 4                   11  45 to 54 years                M2
# ...

# %%
Lib_Use.to_csv("../data/Library_Usage_Projektaufgabe.csv")
