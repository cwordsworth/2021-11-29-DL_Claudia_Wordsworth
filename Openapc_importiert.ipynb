# %%
import urllib.request
import pandas as pd

# %%
openapc_url = "https://raw.githubusercontent.com/OpenAPC/openapc-de/master/data/fuberlin/APC_FU_Berlin_2015.csv"
apc_file = "openapc.csv"

# %%
urllib.request.urlretrieve(openapc_url, apc_file)
# Out:
# ('openapc.csv', <http.client.HTTPMessage at 0x7f940a04bb50>)

# %%
apcs = pd.read_csv(apc_file)

# %%
apcs
# Out:
#    institution  period     euro                           doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00         10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12     10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00            10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00  10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00     10.1186/s13099-015-0075-z      False
# ..         ...     ...      ...                           ...        ...
# 56   FU Berlin    2015  1731.45     10.1186/s13015-014-0028-y      False
# 57   FU Berlin    2015  1600.00      10.3389/fpsyg.2015.00194      False
# 58   FU Berlin    2015   219.84       10.3389/fevo.2015.00020      False
# 59   FU Berlin    2015  1386.35             10.1038/srep19416      False
# 60   FU Berlin    2015  2000.00           10.1155/2015/569512      False
#
#                            publisher                  journal_full_title  \
# ...

# %%
apcs, shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20982/3307255983.py in <module>
# ----> 1 apcs, shape
#
# NameError: name 'shape' is not defined

# %%
apcs,shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20982/3569991131.py in <module>
# ----> 1 apcs,shape
#
# NameError: name 'shape' is not defined

# %%
apcs.shape
# Out:
# (61, 17)

# %%
apcs.columns
# Out:
# Index(['institution', 'period', 'euro', 'doi', 'is_hybrid', 'publisher',
#        'journal_full_title', 'issn', 'issn_print', 'issn_electronic',
#        'license_ref', 'indexed_in_crossref', 'pmid', 'pmcid', 'ut', 'url',
#        'doaj'],
#       dtype='object')

# %%
apcs["euro"]
# Out:
# 0     2000.00
# 1     1503.12
# 2     2000.00
# 3     2000.00
# 4     1805.00
#        ...
# 56    1731.45
# 57    1600.00
# 58     219.84
# 59    1386.35
# 60    2000.00
# Name: euro, Length: 61, dtype: float64

# %%
apcs["euro"].max()
# Out:
# 2000.0

# %%
apcs["euro"].min()
# Out:
# 219.84

# %%
apcs["euro"].mean()
# Out:
# 1419.6080327868851

# %%
apcs["euro"].describe()
# Out:
# count      61.000000
# mean     1419.608033
# std       456.811349
# min       219.840000
# 25%      1178.420000
# 50%      1410.070000
# 75%      1800.000000
# max      2000.000000
# Name: euro, dtype: float64

# %%
? apcs

# %%
? mean
# Out:
# Object ` mean` not found.

# %%
apcs["euro"] >= 2000
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
#       ...
# 56    False
# 57    False
# 58    False
# 59    False
# 60     True
# Name: euro, Length: 61, dtype: bool

# %%
apcs[apcs["euro"] >= 2000]
# Out:
#    institution  period    euro                            doi  is_hybrid  \
# 0    FU Berlin    2015  2000.0          10.1038/npjqi.2015.10      False
# 2    FU Berlin    2015  2000.0             10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.0   10.1371/journal.ppat.1005246      False
# 12   FU Berlin    2015  2000.0       10.3389/fpsyg.2015.01675      False
# 15   FU Berlin    2015  2000.0   10.1371/journal.ppat.1004781      False
# 23   FU Berlin    2015  2000.0         10.1127/metz/2015/0641      False
# 28   FU Berlin    2015  2000.0       10.3389/fnhum.2015.00551      False
# 29   FU Berlin    2015  2000.0             10.1038/ncomms8606      False
# 32   FU Berlin    2015  2000.0      10.1186/s12918-015-0183-x      False
# 45   FU Berlin    2015  2000.0   10.1371/journal.pcbi.1004200      False
# 60   FU Berlin    2015  2000.0            10.1155/2015/569512      False
#
#                            publisher               journal_full_title  \
# ...

# %%
apcs[["euro", "publisher"]]
# Out:
#        euro                         publisher
# 0   2000.00                   Springer Nature
# 1   1503.12   American Physical Society (APS)
# 2   2000.00                   Springer Nature
# 3   2000.00  Public Library of Science (PLoS)
# 4   1805.00                   Springer Nature
# ..      ...                               ...
# 56  1731.45                   Springer Nature
# 57  1600.00                Frontiers Media SA
# 58   219.84                Frontiers Media SA
# 59  1386.35                   Springer Nature
# 60  2000.00    Hindawi Publishing Corporation
#
# [61 rows x 2 columns]

# %%
apcs ["euro"].hist()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>

# %%
apcs [(apcs["euro"] >= 750) & (apcs ["euro"] <= 1050)]
# Out:
#    institution  period    euro                       doi  is_hybrid  \
# 16   FU Berlin    2015  892.50     10.4081/ejh.2015.2516      False
# 38   FU Berlin    2015  895.15       10.1155/2015/235184      False
# 39   FU Berlin    2015  853.84     10.4236/me.2015.66072      False
# 43   FU Berlin    2015  770.00  10.3389/fpsyg.2015.00714      False
# 53   FU Berlin    2015  981.75  10.5194/amtd-8-2623-2015      False
#
#                                publisher  \
# 16                PAGEPress Publications
# 38        Hindawi Publishing Corporation
# 39  Scientific Research Publishing, Inc,
# 43                    Frontiers Media SA
# 53                       Copernicus GmbH
#
#                                 journal_full_title       issn issn_print  \
# 16              European Journal of Histochemistry  2038-8306  1121-760X
# 38                                     Scientifica  2090-908X        NaN
# 39                                  Modern Economy  2152-7245  2152-7245
# ...

# %%
apcs ["euro"].hist(bins=20, color="pink")
# Out:
# <AxesSubplot:>

# %%
apcs ["euro"].hist(bins=25, color="green")
# Out:
# <AxesSubplot:>

# %%
apcs[aps["publisher"] = "Springer Nature")]
# Out:
#   File "/tmp/ipykernel_20982/851584290.py", line 1
#     apcs[(aps["publisher"] = "Springer Nature")]
#                            ^
# SyntaxError: invalid syntax

# %%
apcs ["publisher"]
# Out:
# 0                      Springer Nature
# 1      American Physical Society (APS)
# 2                      Springer Nature
# 3     Public Library of Science (PLoS)
# 4                      Springer Nature
#                     ...
# 56                     Springer Nature
# 57                  Frontiers Media SA
# 58                  Frontiers Media SA
# 59                     Springer Nature
# 60      Hindawi Publishing Corporation
# Name: publisher, Length: 61, dtype: object

# %%
apcs["publisher"] = "Springer Nature"

# %%
apcs[["publisher"] = "Springer Nature"]
# Out:
#   File "/tmp/ipykernel_20982/1828226447.py", line 1
#     apcs[["publisher"] = "Springer Nature"]
#                        ^
# SyntaxError: invalid syntax

# %%
apcs[["euro", "journal_full_title", "doi", "license_ref"]]
# Out:
#         euro journal_full_title       doi license_ref
# 0   Springer           Springer  Springer    Springer
# 1   Springer           Springer  Springer    Springer
# 2   Springer           Springer  Springer    Springer
# 3   Springer           Springer  Springer    Springer
# 4   Springer           Springer  Springer    Springer
# ..       ...                ...       ...         ...
# 56  Springer           Springer  Springer    Springer
# 57  Springer           Springer  Springer    Springer
# 58  Springer           Springer  Springer    Springer
# 59  Springer           Springer  Springer    Springer
# 60  Springer           Springer  Springer    Springer
#
# [61 rows x 4 columns]

# %%
df = apcs[(apcs["publisher"] == "Springer Nature")]
# Out:
# Empty DataFrame
# Columns: [institution, period, euro, doi, is_hybrid, publisher, journal_full_title, issn, issn_print, issn_electronic, license_ref, indexed_in_crossref, pmid, pmcid, ut, url, doaj]
# Index: []

# %%
apcs
# Out:
#    institution    period      euro       doi is_hybrid publisher  \
# 0     Springer  Springer  Springer  Springer  Springer  Springer
# 1     Springer  Springer  Springer  Springer  Springer  Springer
# 2     Springer  Springer  Springer  Springer  Springer  Springer
# 3     Springer  Springer  Springer  Springer  Springer  Springer
# 4     Springer  Springer  Springer  Springer  Springer  Springer
# ..         ...       ...       ...       ...       ...       ...
# 56    Springer  Springer  Springer  Springer  Springer  Springer
# 57    Springer  Springer  Springer  Springer  Springer  Springer
# 58    Springer  Springer  Springer  Springer  Springer  Springer
# 59    Springer  Springer  Springer  Springer  Springer  Springer
# 60    Springer  Springer  Springer  Springer  Springer  Springer
#
#    journal_full_title      issn issn_print issn_electronic license_ref  \
# 0            Springer  Springer   Springer        Springer    Springer
# ...

# %%
apcs [(apcs["euro"] >= 750) & (apcs ["euro"] <= 1050)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_20982/1169733674.py in <module>
# ----> 1 apcs [(apcs["euro"] >= 750) & (apcs ["euro"] <= 1050)]
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in __ge__(self, other)
#      50     @unpack_zerodim_and_defer("__ge__")
#      51     def __ge__(self, other):
# ---> 52         return self._cmp_method(other, operator.ge)
#      53
#      54     # -------------------------------------------------------------
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5500
# ...

# %%
apcs = pd.read_csv(apc_file)

# %%
apcs
# Out:
#    institution  period     euro                           doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00         10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12     10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00            10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00  10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00     10.1186/s13099-015-0075-z      False
# ..         ...     ...      ...                           ...        ...
# 56   FU Berlin    2015  1731.45     10.1186/s13015-014-0028-y      False
# 57   FU Berlin    2015  1600.00      10.3389/fpsyg.2015.00194      False
# 58   FU Berlin    2015   219.84       10.3389/fevo.2015.00020      False
# 59   FU Berlin    2015  1386.35             10.1038/srep19416      False
# 60   FU Berlin    2015  2000.00           10.1155/2015/569512      False
#
#                            publisher                  journal_full_title  \
# ...

# %%
df = apcs[(apcs["publisher"] == "Springer Nature")]

# %%
df [["euro", "journal_full_title", "doi", "license_ref"]]
# Out:
#        euro                journal_full_title                        doi  \
# 0   2000.00           npj Quantum Information      10.1038/npjqi.2015.10
# 2   2000.00             Nature Communications         10.1038/ncomms9498
# 4   1805.00                     Gut Pathogens  10.1186/s13099-015-0075-z
# 13  1165.00                Scientific Reports          10.1038/srep11598
# 14  1386.35                Scientific Reports          10.1038/srep12681
# 24  1249.50                       Pastoralism  10.1186/s13570-015-0035-8
# 25  1625.00               Parasites & Vectors  10.1186/s13071-015-0924-0
# 26  1800.00          BMC Evolutionary Biology  10.1186/s12862-015-0390-5
# 29  2000.00             Nature Communications         10.1038/ncomms8606
# 32  2000.00               BMC Systems Biology  10.1186/s12918-015-0183-x
# 54  1969.45           BMC Veterinary Research  10.1186/s12917-015-0351-7
# 56  1731.45  Algorithms for Molecular Biology  10.1186/s13015-014-0028-y
# ...

# %%
apcs[(apcs["publisher"] == "Springer Nature")][["euro", "journal_full_title", "doi", "license_ref"]]
# Out:
#        euro                journal_full_title                        doi  \
# 0   2000.00           npj Quantum Information      10.1038/npjqi.2015.10
# 2   2000.00             Nature Communications         10.1038/ncomms9498
# 4   1805.00                     Gut Pathogens  10.1186/s13099-015-0075-z
# 13  1165.00                Scientific Reports          10.1038/srep11598
# 14  1386.35                Scientific Reports          10.1038/srep12681
# 24  1249.50                       Pastoralism  10.1186/s13570-015-0035-8
# 25  1625.00               Parasites & Vectors  10.1186/s13071-015-0924-0
# 26  1800.00          BMC Evolutionary Biology  10.1186/s12862-015-0390-5
# 29  2000.00             Nature Communications         10.1038/ncomms8606
# 32  2000.00               BMC Systems Biology  10.1186/s12918-015-0183-x
# 54  1969.45           BMC Veterinary Research  10.1186/s12917-015-0351-7
# 56  1731.45  Algorithms for Molecular Biology  10.1186/s13015-014-0028-y
# ...

# %%
apcs[(apcs["publisher"] == "Springer Nature")
     & (apcs["euro"] >= 1000)][["euro", "journal_full_title", "doi", "license_ref"]]
# Out:
#        euro                journal_full_title                        doi  \
# 0   2000.00           npj Quantum Information      10.1038/npjqi.2015.10
# 2   2000.00             Nature Communications         10.1038/ncomms9498
# 4   1805.00                     Gut Pathogens  10.1186/s13099-015-0075-z
# 13  1165.00                Scientific Reports          10.1038/srep11598
# 14  1386.35                Scientific Reports          10.1038/srep12681
# 24  1249.50                       Pastoralism  10.1186/s13570-015-0035-8
# 25  1625.00               Parasites & Vectors  10.1186/s13071-015-0924-0
# 26  1800.00          BMC Evolutionary Biology  10.1186/s12862-015-0390-5
# 29  2000.00             Nature Communications         10.1038/ncomms8606
# 32  2000.00               BMC Systems Biology  10.1186/s12918-015-0183-x
# 54  1969.45           BMC Veterinary Research  10.1186/s12917-015-0351-7
# 56  1731.45  Algorithms for Molecular Biology  10.1186/s13015-014-0028-y
# ...

# %%
apcs[(apcs["publisher"] == "Springer Nature")
     & (apcs["euro"] >= 1000)][["euro", "journal_full_title", "doi", "license_ref", "publisher"]]
# Out:
#        euro                journal_full_title                        doi  \
# 0   2000.00           npj Quantum Information      10.1038/npjqi.2015.10
# 2   2000.00             Nature Communications         10.1038/ncomms9498
# 4   1805.00                     Gut Pathogens  10.1186/s13099-015-0075-z
# 13  1165.00                Scientific Reports          10.1038/srep11598
# 14  1386.35                Scientific Reports          10.1038/srep12681
# 24  1249.50                       Pastoralism  10.1186/s13570-015-0035-8
# 25  1625.00               Parasites & Vectors  10.1186/s13071-015-0924-0
# 26  1800.00          BMC Evolutionary Biology  10.1186/s12862-015-0390-5
# 29  2000.00             Nature Communications         10.1038/ncomms8606
# 32  2000.00               BMC Systems Biology  10.1186/s12918-015-0183-x
# 54  1969.45           BMC Veterinary Research  10.1186/s12917-015-0351-7
# 56  1731.45  Algorithms for Molecular Biology  10.1186/s13015-014-0028-y
# ...
